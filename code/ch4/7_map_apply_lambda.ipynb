# %%
import pandas as pd
import numpy as np

# %%
from pandas import Series

# %% [markdown]
# ### lambda

# %%
f = lambda x,y: x + y
f(1,4)
# Out:
# 5

# %%
def f(x , y):
    return x + y

# %%
f = lambda x: x ** 2
f(3)
# Out:
# 9

# %%
f = lambda x: x / 2
f(3)
# Out:
# 1.5

# %%
(lambda x: x +1)(5)
# Out:
# 6

# %% [markdown]
# ### map & replace

# %%
ex = [1,2,3,4,5]
f = lambda x: x ** 2
list(map(f, ex))
# Out:
# [1, 4, 9, 16, 25]

# %%
f = lambda x, y: x + y
list(map(f, ex, ex))
# Out:
# [2, 4, 6, 8, 10]

# %%
list(map(lambda x: x+x, ex)) 
#python 3에는 list를 꼭 붙여줘야함
# Out:
# [2, 4, 6, 8, 10]

# %%
s1 = Series(np.arange(10))
s1.head(5)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
s1.map(lambda x: x**2).head(5)
# Out:
# 0     0
# 1     1
# 2     4
# 3     9
# 4    16
# dtype: int64

# %%
z = {1: 'A', 2: 'B', 3: 'C'}
s1.map(z).head(5)
# Out:
# 0    NaN
# 1      A
# 2      B
# 3      C
# 4    NaN
# dtype: object

# %%
s2 = Series(np.arange(10,20))
s1.map(s2).head(5)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64

# %%
# !wget https://raw.githubusercontent.com/rstudio/Intro/master/data/wages.csv
# Out:
# --2017-10-02 15:47:08--  https://raw.githubusercontent.com/rstudio/Intro/master/data/wages.csv
# Resolving raw.githubusercontent.com... 151.101.88.133
# Connecting to raw.githubusercontent.com|151.101.88.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62250 (61K) [text/plain]
# Saving to: 'wages.csv.2'
#
# wages.csv.2         100%[===================>]  60.79K  --.-KB/s    in 0.08s
#
# 2017-10-02 15:47:10 (734 KB/s) - 'wages.csv.2' saved [62250/62250]

# %%
df = pd.read_csv("wages.csv")
df.head()
# Out:
#            earn  height     sex   race  ed  age
# 0  79571.299011   73.89    male  white  16   49
# 1  96396.988643   66.23  female  white  16   62
# 2  48710.666947   63.77  female  white  16   33
# 3  80478.096153   63.22  female  other  16   95
# 4  82089.345498   63.08  female  white  17   43

# %%
df.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["sex_code"] = df.sex.map({"male":0, "female":1})
df.head(5)
# Out:
#            earn  height     sex   race  ed  age  sex_code
# 0  79571.299011   73.89    male  white  16   49         0
# 1  96396.988643   66.23  female  white  16   62         1
# 2  48710.666947   63.77  female  white  16   33         1
# 3  80478.096153   63.22  female  other  16   95         1
# 4  82089.345498   63.08  female  white  17   43         1

# %%
df.sex.replace(
    {"male":0, "female":1}
).head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: sex, dtype: int64

# %%
df.sex.replace(
    ["male", "female"], 
    [0,1], inplace=True)
df.head(5)
# Out:
#            earn  height  sex   race  ed  age  sex_code
# 0  79571.299011   73.89    0  white  16   49         0
# 1  96396.988643   66.23    1  white  16   62         1
# 2  48710.666947   63.77    1  white  16   33         1
# 3  80478.096153   63.22    1  other  16   95         1
# 4  82089.345498   63.08    1  white  17   43         1

# %% [markdown]
# ### apply & applymap

# %%
df = pd.read_csv("wages.csv")
df.head()
# Out:
#            earn  height     sex   race  ed  age
# 0  79571.299011   73.89    male  white  16   49
# 1  96396.988643   66.23  female  white  16   62
# 2  48710.666947   63.77  female  white  16   33
# 3  80478.096153   63.22  female  other  16   95
# 4  82089.345498   63.08  female  white  17   43

# %%
df_info = df[["earn", "height","age"]]
df_info.head()
# Out:
#            earn  height  age
# 0  79571.299011   73.89   49
# 1  96396.988643   66.23   62
# 2  48710.666947   63.77   33
# 3  80478.096153   63.22   95
# 4  82089.345498   63.08   43

# %%
f = lambda x : x.max() - x.min()
df_info.apply(f)
# Out:
# earn      318047.708444
# height        19.870000
# age           73.000000
# dtype: float64

# %%
df_info.apply(sum)
# Out:
# earn      4.474344e+07
# height    9.183125e+04
# age       6.250800e+04
# dtype: float64

# %%
df_info.sum()
# Out:
# earn      4.474344e+07
# height    9.183125e+04
# age       6.250800e+04
# dtype: float64

# %%
def f(x):
    return Series([x.min(), x.max()], index=["min", "max"])
df_info.apply(f)
# Out:
#               earn  height  age
# min     -98.580489   57.34   22
# max  317949.127955   77.21   95

# %%
f = lambda x : -x
df_info.applymap(f).head(5)
# Out:
#            earn  height  age
# 0 -79571.299011  -73.89  -49
# 1 -96396.988643  -66.23  -62
# 2 -48710.666947  -63.77  -33
# 3 -80478.096153  -63.22  -95
# 4 -82089.345498  -63.08  -43

# %%
f = lambda x : -x
df_info["earn"].apply(f).head(5)
# Out:
# 0   -79571.299011
# 1   -96396.988643
# 2   -48710.666947
# 3   -80478.096153
# 4   -82089.345498
# Name: earn, dtype: float64
