# %%
import pandas as pd
from pandas import Series
from pandas import DataFrame

import numpy as np

# %% [markdown]
# ### Built-in functions

# %%
df = pd.read_csv("wages.csv")
df.head()
# Out:
#            earn  height     sex   race  ed  age
# 0  79571.299011   73.89    male  white  16   49
# 1  96396.988643   66.23  female  white  16   62
# 2  48710.666947   63.77  female  white  16   33
# 3  80478.096153   63.22  female  other  16   95
# 4  82089.345498   63.08  female  white  17   43

# %%
df.describe()
# Out:
#                 earn       height           ed          age
# count    1379.000000  1379.000000  1379.000000  1379.000000
# mean    32446.292622    66.592640    13.354605    45.328499
# std     31257.070006     3.818108     2.438741    15.789715
# min       -98.580489    57.340000     3.000000    22.000000
# 25%     10538.790721    63.720000    12.000000    33.000000
# 50%     26877.870178    66.050000    13.000000    42.000000
# 75%     44506.215336    69.315000    15.000000    55.000000
# max    317949.127955    77.210000    18.000000    95.000000

# %%
df.race.unique()
# Out:
# array(['white', 'other', 'hispanic', 'black'], dtype=object)

# %%
np.array(dict(enumerate(df["race"].unique())))
# Out:
# array({0: 'white', 1: 'other', 2: 'hispanic', 3: 'black'}, dtype=object)

# %%
value = list(map(int, np.array(list(enumerate(df["race"].unique())))[:, 0].tolist()))
key = np.array(list(enumerate(df["race"].unique())), dtype=str)[:, 1].tolist()

value, key
# Out:
# ([0, 1, 2, 3], ['white', 'other', 'hispanic', 'black'])

# %%
df["race"].replace(to_replace=key, value=value, inplace=True)

# %%
value = list(map(int, np.array(list(enumerate(df["sex"].unique())))[:, 0].tolist()))
key = np.array(list(enumerate(df["sex"].unique())), dtype=str)[:, 1].tolist()

value, key
# Out:
# ([0, 1], ['male', 'female'])

# %%
df["sex"].replace(to_replace=key, value=value, inplace=True)
df.head(5)
# Out:
#            earn  height  sex  race  ed  age
# 0  79571.299011   73.89    0     0  16   49
# 1  96396.988643   66.23    1     0  16   62
# 2  48710.666947   63.77    1     0  16   33
# 3  80478.096153   63.22    1     1  16   95
# 4  82089.345498   63.08    1     0  17   43

# %%
df.sum(axis=0)
# Out:
# earn      4.474344e+07
# height    9.183125e+04
# sex       8.590000e+02
# race      5.610000e+02
# ed        1.841600e+04
# age       6.250800e+04
# dtype: float64

# %%
df.sum(axis=1)
# Out:
# 0        79710.189011
# 1        96542.218643
# 2        48824.436947
# 3        80654.316153
# 4        82213.425498
# 5        15423.882901
# 6        47231.711821
# 7        51100.344282
# 8         3326.889556
# 9        43111.037884
# 10       10483.838843
# 11        1134.457155
# 12       47714.929864
# 13       19130.622299
# 14       20196.856639
# 15        1096.892346
# 16       36094.181123
# 17       27072.613964
# 18       64718.223972
# 19       70124.713070
# 20        1102.298306
# 21       12271.022115
# 22       84351.157919
# 23        9080.644935
# 24       23381.363278
# 25        8856.809185
# 26       64717.549805
# 27       54212.504945
# 28       17013.860044
# 29           8.749721
#             ...
# 1349     64753.641872
# 1350     16059.423155
# 1351     25480.928379
# 1352     18611.227184
# 1353     26561.776457
# 1354     28757.820098
# 1355     20175.062736
# 1356      6466.932127
# 1357     95549.526798
# 1358     68564.843058
rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# earn      0
# height    0
# sex       0
# race      0
# ed        0
# age       0
# dtype: int64

# %%
df.sort_values(["age", "earn"], ascending=True).head(10)
# Out:
#              earn  height  sex  race  ed  age
# 1038   -56.321979   67.81    0     2  10   22
# 800    -27.876819   72.29    0     0  12   22
# 963    -25.655260   68.90    0     0  12   22
# 1105   988.565070   64.71    1     0  12   22
# 801   1000.221504   64.09    1     0  12   22
# 862   1002.023843   66.59    1     0  12   22
# 933   1007.994941   68.26    1     0  12   22
# 988   1578.542814   64.53    0     0  12   22
# 522   1955.168187   69.87    1     3  12   22
# 765   2581.870402   64.79    1     0  12   22

# %%
df.cumsum().head(5)
# Out:
#             earn  height  sex  race    ed    age
# 0   79571.299011   73.89  0.0   0.0  16.0   49.0
# 1  175968.287654  140.12  1.0   0.0  32.0  111.0
# 2  224678.954602  203.89  2.0   0.0  48.0  144.0
# 3  305157.050754  267.11  3.0   1.0  64.0  239.0
# 4  387246.396253  330.19  4.0   1.0  81.0  282.0

# %%
df.cummax().head(10)
# Out:
#            earn  height  sex  race    ed   age
# 0  79571.299011   73.89  0.0   0.0  16.0  49.0
# 1  96396.988643   73.89  1.0   0.0  16.0  62.0
# 2  96396.988643   73.89  1.0   0.0  16.0  62.0
# 3  96396.988643   73.89  1.0   1.0  16.0  95.0
# 4  96396.988643   73.89  1.0   1.0  17.0  95.0
# 5  96396.988643   73.89  1.0   1.0  17.0  95.0
# 6  96396.988643   73.89  1.0   1.0  17.0  95.0
# 7  96396.988643   73.89  1.0   1.0  17.0  95.0
# 8  96396.988643   73.89  1.0   2.0  17.0  95.0
# 9  96396.988643   73.89  1.0   2.0  17.0  95.0

# %%
df.sort_values("age", ascending=False).head(10)
# Out:
#               earn  height  sex  race  ed  age
# 3     80478.096153   63.22    1     1  16   95
# 331   39169.750135   64.79    1     0  12   95
# 809   42963.362005   72.94    0     0  12   95
# 102   39751.194030   67.14    0     0  12   93
# 993   32809.632677   59.61    1     1  16   92
# 1017   8942.806716   62.97    1     0  10   91
# 1192  39757.947210   64.79    0     0  16   90
# 952    8162.682672   58.09    1     0   5   89
# 827   55712.348432   70.13    0     0   9   88
# 1068  10861.092284   64.03    1     0  13   87

# %%
df.age.corr(df.earn)
# Out:
# 0.074003491778360575

# %%
df.age.cov(df.earn)
# Out:
# 36523.6992104089

# %%
df.corr()
# Out:
#             earn    height       sex      race        ed       age
# earn    1.000000  0.291600 -0.337328 -0.063977  0.350374  0.074003
# height  0.291600  1.000000 -0.703672 -0.045974  0.114047 -0.133727
# sex    -0.337328 -0.703672  1.000000  0.000858 -0.061747  0.070036
# race   -0.063977 -0.045974  0.000858  1.000000 -0.049487 -0.056879
# ed      0.350374  0.114047 -0.061747 -0.049487  1.000000 -0.129802
# age     0.074003 -0.133727  0.070036 -0.056879 -0.129802  1.000000

# %%
df.corrwith(df.earn)
# Out:
# earn      1.000000
# height    0.291600
# sex      -0.337328
# race     -0.063977
# ed        0.350374
# age       0.074003
# dtype: float64

# %%
df.sex.value_counts(sort=True)
# Out:
# 1    859
# 0    520
# Name: sex, dtype: int64

# %%
df_time_serires = pd.read_csv("./AirPassengers.csv")
df_time_serires.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df_time_serires["step"] = range(len(df_time_serires))
df_time_serires["cum_pass"] = df_time_serires["#Passengers"].cumsum()
df_time_serires["cum_max"] = df_time_serires["#Passengers"].cummax()
df_time_serires["cum_min"] = df_time_serires["#Passengers"].cummin()
df_time_serires.head(5)
# Out:
#      Month  #Passengers  step  cum_pass  cum_max  cum_min
# 0  1949-01          112     0       112      112      112
# 1  1949-02          118     1       230      118      112
# 2  1949-03          132     2       362      132      112
# 3  1949-04          129     3       491      132      112
# 4  1949-05          121     4       612      132      112

# %%
df_time_serires["date"] = df_time_serires["Month"].map(lambda x: str(x)+"-01")
del df_time_serires["Month"]
df_time_serires.head(5)
# Out:
#    #Passengers  step  cum_pass  cum_max  cum_min        date
# 0          112     0       112      112      112  1949-01-01
# 1          118     1       230      118      112  1949-02-01
# 2          132     2       362      132      112  1949-03-01
# 3          129     3       491      132      112  1949-04-01
# 4          121     4       612      132      112  1949-05-01

# %%
temp_date = df_time_serires["date"].map(lambda x: x.split("-"))
np_date = np.array(temp_date.values.tolist())
year = np_date[:, 0]
month = np_date[:, 1]
day = np_date[:, 2]
df_time_serires["year"] = year
df_time_serires["month"] = month
df_time_serires.head()
# Out:
#    #Passengers  step  cum_pass  cum_max  cum_min        date  year month
# 0          112     0       112      112      112  1949-01-01  1949    01
# 1          118     1       230      118      112  1949-02-01  1949    02
# 2          132     2       362      132      112  1949-03-01  1949    03
# 3          129     3       491      132      112  1949-04-01  1949    04
# 4          121     4       612      132      112  1949-05-01  1949    05

# %%
df_time_serires["diff"] = df_time_serires["#Passengers"].diff().fillna(0)

# %%
df_time_serires.head()
# Out:
#    #Passengers  step  cum_pass  cum_max  cum_min        date  year month  diff
# 0          112     0       112      112      112  1949-01-01  1949    01   0.0
# 1          118     1       230      118      112  1949-02-01  1949    02   6.0
# 2          132     2       362      132      112  1949-03-01  1949    03  14.0
# 3          129     3       491      132      112  1949-04-01  1949    04  -3.0
# 4          121     4       612      132      112  1949-05-01  1949    05  -8.0

# %%
df_time_serires["diff_cumsum"] = df_time_serires["diff"].cumsum()
df_time_serires.head(10)
# Out:
#    #Passengers  step  cum_pass  cum_max  cum_min        date  year month  \
# 0          112     0       112      112      112  1949-01-01  1949    01
# 1          118     1       230      118      112  1949-02-01  1949    02
# 2          132     2       362      132      112  1949-03-01  1949    03
# 3          129     3       491      132      112  1949-04-01  1949    04
# 4          121     4       612      132      112  1949-05-01  1949    05
# 5          135     5       747      135      112  1949-06-01  1949    06
# 6          148     6       895      148      112  1949-07-01  1949    07
# 7          148     7      1043      148      112  1949-08-01  1949    08
# 8          136     8      1179      148      112  1949-09-01  1949    09
# 9          119     9      1298      148      112  1949-10-01  1949    10
#
#    diff  diff_cumsum
# 0   0.0          0.0
# 1   6.0          6.0
# 2  14.0         20.0
# 3  -3.0         17.0
# 4  -8.0          9.0
# 5  14.0         23.0
# 6  13.0         36.0
# 7   0.0         36.0
# 8 -12.0         24.0
# 9 -17.0          7.0

# %%
df_time_serires["passen_dailty_pct"] = df_time_serires["#Passengers"].pct_change().map(lambda x: x *100).map(lambda x: '%.2f' % x)
df_time_serires
# Out:
#      #Passengers  step  cum_pass  cum_max  cum_min        date  year month  \
# 0            112     0       112      112      112  1949-01-01  1949    01
# 1            118     1       230      118      112  1949-02-01  1949    02
# 142          390   142     39931      622      104  1960-11-01  1960    11
# 143          432   143     40363      622      104  1960-12-01  1960    12
#
#       diff  diff_cumsum passen_dailty_pct
# 0      0.0          0.0               nan
# 1      6.0          6.0              5.36
# 2     14.0         20.0             11.86
# 3     -3.0         17.0             -2.27
# 4     -8.0          9.0             -6.20
# 5     14.0         23.0             11.57
# 6     13.0         36.0              9.63
# 7      0.0         36.0              0.00
# 8    -12.0         24.0             -8.11
# 9    -17.0          7.0            -12.50
# 10   -15.0         -8.0            -12.61
# 11    14.0          6.0             13.46
# 12    -3.0          3.0             -2.54
# 13    11.0         14.0              9.57
# 14    15.0         29.0             11.90
# 15    -6.0         23.0             -4.26
# 16   -10.0         13.0             -7.41
# 17    24.0         37.0             19.20
# 18    21.0         58.0             14.09
# 19     0.0         58.0              0.00
# 20   -12.0         46.0             -7.06
# 21   -25.0         21.0            -15.82
# 22   -19.0          2.0            -14.29
# 23    26.0         28.0             22.81
# 24     5.0         33.0              3.57
# 25     5.0         38.0              3.45
# 26    28.0         66.0             18.67
# 27   -15.0         51.0             -8.43
# 28     9.0         60.0              5.52
# 29     6.0         66.0              3.49
# ..     ...          ...               ...
# 114   56.0        379.0             12.87
# 115   14.0        393.0              2.85
# 116 -101.0        292.0            -20.00
# 117  -45.0        247.0            -11.14
# 118  -49.0        198.0            -13.65
# 119   27.0        225.0              8.71
# 120   23.0        248.0              6.82
# 121  -18.0        230.0             -5.00
# 122   64.0        294.0             18.71
# 123  -10.0        284.0             -2.46
# 124   24.0        308.0              6.06
# 125   52.0        360.0             12.38
# 126   76.0        436.0             16.10
# 127   11.0        447.0              2.01
# 128  -96.0        351.0            -17.17
# 129  -56.0        295.0            -12.10
# 130  -45.0        250.0            -11.06
# 131   43.0        293.0             11.88
# 132   12.0        305.0              2.96
# 133  -26.0        279.0             -6.24
# 134   28.0        307.0              7.16
# 135   42.0        349.0             10.02
# 136   11.0        360.0              2.39
# 137   63.0        423.0             13.35
# 138   87.0        510.0             16.26
# 139  -16.0        494.0             -2.57
# 140  -98.0        396.0            -16.17
# 141  -47.0        349.0             -9.25
# 142  -71.0        278.0            -15.40
# 143   42.0        320.0             10.77
#
# [144 rows x 11 columns]

# %%
df_time_serires.groupby(["year"]).sum()
# Out:
#       #Passengers  step  cum_pass  cum_max  cum_min  diff  diff_cumsum
# year
# 1949         1520    66      9891     1649     1328   6.0        176.0
# 1950         1676   210     28943     1909     1248  22.0        332.0
# 1951         2042   354     51480     2246     1248  26.0        698.0
# 1952         2364   498     77974     2653     1248  28.0       1020.0
# 1953         2700   642    108826     3077     1248   7.0       1356.0
# 1954         2867   786    141888     3444     1248  28.0       1523.0
# 1955         3408   930    179692     4009     1248  49.0       2064.0
# 1956         3939  1074    224217     4672     1248  28.0       2595.0
# 1957         4421  1218    274497     5287     1248  30.0       3077.0
# 1958         4572  1362    328644     5818     1248   1.0       3228.0
# 1959         5140  1506    386763     6373     1248  68.0       3796.0
# 1960         5714  1650    452342     7086     1248  27.0       4370.0
