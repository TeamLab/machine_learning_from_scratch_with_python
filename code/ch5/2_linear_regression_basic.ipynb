# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
raw_data = np.loadtxt('data/unemployment.csv', 
           delimiter=',', usecols=(0,1), 
           unpack=True, dtype=float, skiprows=1)

print(list(raw_data))
# Out:
# [array([  6.2,   9.5,  10.5,   7.7,   8.6,  34.1,  11. ,   6.9,   7.3,
#         15.1,  29.1,   2.2,   5.7,   2. ,   2.5,   4. ,   5.4,   2.2,
#          7.2,  15.1,  16.5,  18.4,  36.2,  39.7,  18.5,  23.3,  12.2,
#          5.6,  21.8,  21.6,   9. ,   3.6,   5. ,  28.6,  17.4,  11.3,
#          3.4,  11.9,  10.5,  10.7,  10.8,   4.8]), array([  29.,   44.,   36.,   37.,   53.,   68.,   75.,   18.,   31.,
#          25.,   34.,   14.,   11.,   11.,   22.,   16.,   27.,    9.,
#          29.,   30.,   40.,   32.,   41.,  147.,   22.,   29.,   46.,
#          23.,    4.,   31.,   39.,   15.,   32.,   27.,   32.,   34.,
#          17.,   46.,   42.,   43.,   34.,   19.])]

# %%
x_data = raw_data [0]
y_data = raw_data [1]

# Drawing scatter plot
plt.plot(x_data, y_data, "ro")
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
def least_squares_fit(x,y):
    """given training values for x and y,
    find the least-squares values of alpha and beta"""
    beta = np.dot((x-np.mean(x)), (y-np.mean(y)))  / sum((x-np.mean(x)) ** 2)
    alpha = np.mean(y) - beta * np.mean(x)
    return alpha, beta

alpha, beta = least_squares_fit(x_data, y_data)
print("alpha", alpha)
print("beta", beta)
# Out:
# alpha 16.9951572327
# beta 1.31345600492

# %%
# Y = alpha + beta * X
# Drawing scatter plot

plt.plot(x_data, y_data, "ro")
plt.plot(x_data, alpha + beta * x_data)
plt.show()

# %%
def your_first_model(x_value):
    return 16.9951572327 + x_value * 1.31345600492

your_first_model(10)
# Out:
# 30.1297172819
